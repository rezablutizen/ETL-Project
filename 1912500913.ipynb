# %%
import pandas as pd

# %%
data1 = pd.read_csv('data1.csv')
data2 = pd.read_csv('data2.csv')

# %%
data = data1.merge(data2, how='left')

# %%
data = data.drop(columns=['color', 'language'])

# %%
data['director_name'].fillna('N/A', inplace = True)

# %%
data['gross'].fillna(0, inplace = True)

# %%
data['movie_title'] = data['movie_title'].str.replace('é', 'e')

# %%
data['country'] = data['country'].str.upper()
data['country'].replace('UNITED STATES', 'USA', inplace = True)

# %%
for i in range(len(data)):
  if data['duration'][i] <= 10 or data['duration'][i] > 300:
    data['duration'][i] = 0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for i in range(len(data)):
  if data['imdb_score'][i] <= 0:
    data['imdb_score'][i] = 0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data[['actors1','actors2','actors3']] = data.actors.str.split(',', expand = True)

# %%
data
# Out:
#            director_name  duration  ...               actors2                actors3
# 0        Martin Scorsese       240  ...   Matthew McConaughey            Jon Favreau
# 1            Shane Black       195  ...           Jon Favreau            Don Cheadle
# 2      Quentin Tarantino       187  ...  Jennifer Jason Leigh               Zoë Bell
# 3       Kenneth Lonergan       186  ...         Kieran Culkin     John Gallagher Jr.
# 4          Peter Jackson       186  ...            Adam Brown          James Nesbitt
# 5                    N/A       183  ...          Lauren Cohan         Alan D. Purwin
# 6          Peter Jackson         0  ...            Adam Brown          James Nesbitt
# 7            Edward Hall       180  ...         Hayley Atwell     Charlotte Rampling
# 8            Joss Whedon       173  ...     Robert Downey Jr.     Scarlett Johansson
# 9            Joss Whedon       173  ...     Robert Downey Jr.     Scarlett Johansson
# 10            Tom Tykwer       172  ...          Jim Sturgess          Jim Broadbent
# 11                  Null       158  ...         Goran Visnjic       Joely Richardson
# 12   Christopher Spencer       170  ...      Amber Rose Revah            Darwin Shaw
# 13     Christopher Nolan       169  ...         Anne Hathaway          Mackenzie Foy
# 14          F. Gary Gray       167  ...        Neil Brown Jr.       R. Marcos Taylor
# 15     Richard Linklater       165  ...     Lorelei Linklater          Libby Villari
# 16     Quentin Tarantino         0  ...       Christoph Waltz           Ato Essandoh
# 17           Michael Bay       165  ...          Sophia Myles         Kelsey Grammer
# 18     Christopher Nolan       164  ...        Christian Bale   Joseph Gordon-Levitt
# 19         Peter Jackson       164  ...            Adam Brown          James Nesbitt
# 20            Tom Hooper       158  ...        Eddie Redmayne          Anne Hathaway
# 21            Tom Hooper       158  ...        Eddie Redmayne          Anne Hathaway
# 22       Kathryn Bigelow       157  ...      Harold Perrineau         Parker Sawyers
# 23          Ridley Scott       156  ...          William Hurt           Scott Grimes
# 24                   N/A       156  ...             Tom Hardy             Lukas Haas
# 25           Michael Bay       154  ...        Lester Speight             Kevin Dunn
# 26      Denis Villeneuve       153  ...       Jake Gyllenhaal         Dylan Minnette
# 27     Gnana Rajasekaran       153  ...        Michael Lieber          Kevin McGowan
# 28             Marc Webb       153  ...       Andrew Garfield            Chris Zylka
# 29                   Nan       151  ...         Donald Glover          Benedict Wong
# 30          Ridley Scott       150  ...        María Valverde         Ben Mendelsohn
# 31          Ridley Scott       150  ...        María Valverde         Ben Mendelsohn
# 32                   N/A       150  ...          Hal Holbrook           Bruce McGill
# 33            Mike Leigh       150  ...            Ruth Sheen           Karl Johnson
# 34        Gore Verbinski         0  ...           Ruth Wilson          Tom Wilkinson
# 35         David Fincher       149  ...             Sela Ward      Emily Ratajkowski
# 36          Bryan Singer       149  ...        Peter Dinklage           Hugh Jackman
# 37             Jay Oliva       148  ...           Mark Valley           Grey Griffin
# 38     Christopher Nolan       148  ...             Tom Hardy   Joseph Gordon-Levitt
# 39  Paul Thomas Anderson       148  ...   Katherine Waterston    Serena Scott Thomas
# 40            Sam Mendes       148  ...          Rory Kinnear       Stephanie Sigman
# 41                   N/A       147  ...    Scarlett Johansson            Chris Evans
# 42  Michael Patrick King       146  ...         Liza Minnelli          Kristin Davis
# 43           Tate Taylor       146  ...   Bryce Dallas Howard             Mike Vogel
# 44      Francis Lawrence       146  ...       Josh Hutcherson  Sandra Ellis Lafferty
# 45      Steven Spielberg       146  ...  Benedict Cumberbatch           Eddie Marsan
# 46           Michael Bay       144  ...      James Badge Dale        David Costabile
# 47       Guillaume Canet       144  ...           Lili Taylor           Billy Crudup
# 48  Paul Thomas Anderson       144  ...    Jeffrey W. Jenkins        Bruce Goodchild
#
# [49 rows x 14 columns]

# %%
data.to_json('1912500913_RezaKurniawan.json')

# %%
import pymysql


# Connect to the database
connection = pymysql.connect(host='localhost',
                         user='root',
                         password='12345',
                         db='db_1912500913_RezaKurniawan')


# create cursor
cursor=connection.cursor()

# %%
cols = "`,`".join([str(i) for i in data.columns.tolist()])

# %%
for i,row in data.iterrows():
    sql = "INSERT INTO `uas_1912500913_RezaKurniawan` (`" +cols + "`) VALUES (" + "%s,"*(len(row)-1) + "%s)"
    cursor.execute(sql, tuple(row))
    connection.commit()
